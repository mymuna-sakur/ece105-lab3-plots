# %%
# Generate simulated temperature readings from two sensors.
# Sensor A: mean 25 C, std 3 C, 200 readings.
# Sensor B: mean 27 C, std 4.5 C, 200 readings.
# Also generate 200 timestamps uniformly from 0 to 10 seconds.
# Use np.random.default_rng with a seed = 2223.
import numpy as np
import matplotlib.pyplot as plt

rng = np.random.default_rng(seed=2223)

sensor_a = rng.normal(loc=25.0, scale=3.0, size=200)
sensor_b = rng.normal(loc=27.0, scale=4.5, size=200)
timestamps = rng.uniform(low=0.0, high=10.0, size=200)

print(sensor_a.shape)
print(sensor_b.shape)
print(timestamps.shape)
# Out:
# (200,)
# (200,)
# (200,)

# %%
# Scatter plot: sensor reading (y-axis) vs timestamp in seconds (x-axis).
# Color Sensor A points blue and Sensor B points orange.
# Add axis labels with units, a title, and a legend.
plt.figure(figsize=(8,5))
plt.scatter(timestamps, sensor_a, s=20, alpha=0.7, color='blue', label='Sensor A')
plt.scatter(timestamps, sensor_b, s=20, alpha=0.7, color='orange', label='Sensor B')
plt.xlabel('Time (s)')
plt.ylabel('Temperature (°C)')
plt.title('Sensor A and B Readings vs Time')
plt.legend()
plt.show()

# %%
# Overlaid histogram of Sensor A and Sensor B temperature distributions.
# Use 30 bins, alpha=0.5 for transparency so both distributions are visible.
# Add vertical dashed lines at each sensor's mean.
# Include a legend labeling each sensor.
plt.figure(figsize=(8,5))
plt.hist(sensor_a, bins=30, alpha=0.5, color='blue', label='Sensor A')
plt.hist(sensor_b, bins=30, alpha=0.5, color='orange', label='Sensor B')
plt.axvline(sensor_a.mean(), color='blue', linestyle='dashed', linewidth=1.5, label='Mean A')
plt.axvline(sensor_b.mean(), color='orange', linestyle='dashed', linewidth=1.5, label='Mean B')
plt.xlabel('Temperature (°C)')
plt.ylabel('Count')
plt.title('Temperature Distribution: Sensor A vs Sensor B')
plt.legend()
plt.show()

# %%
# Side-by-side box plot comparing Sensor A and Sensor B distributions.
# Label x-axis with sensor names, y-axis with "Temperature (deg C)".
# Add a horizontal dashed line at the overall mean of both sensors combined.
fig, ax = plt.subplots()
ax.boxplot([sensor_a, sensor_b], labels=['Sensor A', 'Sensor B'])
overall_mean = np.mean(np.concatenate([sensor_a, sensor_b]))
ax.axhline(overall_mean, color='red', linestyle='dashed', linewidth=1.5, label='Overall Mean')
ax.set_xlabel('Sensor')
ax.set_ylabel('Temperature (deg C)')
ax.set_title('Sensor A vs Sensor B Temperature Distribution')
ax.legend()
plt.show()
# Out:
# C:\Users\msaku\AppData\Local\Temp\ipykernel_6304\3652870355.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([sensor_a, sensor_b], labels=['Sensor A', 'Sensor B'])
